# %% [markdown]
# # Google Colaboratory
#
# <img src="https://miro.medium.com/max/3600/1*7oukapIBInsovpHkQB3QZg.jpeg">

# %% [markdown]
# #### Colab이란 무엇인가?
#
# 구글 코랩(Colab)은 __클라우드 기반의 Jupyter 노트북 개발 환경__이다.
#
# - 내부적으로는 **코랩 + 구글드라이브 + 도커 + 리눅스 + 구글클라우드**의 기술스택으로 이루어진 것으로 알려져있다.
# - 공짜다. 물론 유료 서비스인 Colab Pro(월:$9.99+tax)가 있다
# - 클라우드 기반으로 환경설정 및 구동 준비가 5분이면 끝난다.
#     - 대부분의 패키지들이 설치되어 있는 환경
# - 브라우저(Chrome, Safari, Firefox)기반으로 PC, tablet, smartphone등 브라우저가 설치된 모든 디바이스에서 구동
# - 어지간한 개인 PC보다 성능이 좋고 빠르다.
# - 일반 Jupyter Notebook에 비해 더 좋은 기능을 제공한다. (목차기능, Markdown의 미리보기 기능 등)
# - *__Google Drive, Git, Github__*와의 연동이 가능
# - 오류발생 시 [SEARCH STACK OVERFLOW] 버튼을 클릭하면 자동으로 스택오버플로우 사이트 검색
#
# __사용시 주의할 점__
# - 구글계정이 필요
# - __최대 세션 유지시간은 무료서비스는 12시간__, 유료인 Colab Pro는 24시간 이다.
#     - 아무짓도 안하거나 또는 유지시간이 지나면 알아서 세션이 끊긴다.
# - 세션이 끊기면? 작업중이던 데이터가 다 날라간다
#     - __소스코드는 .ipynb 확장자로 구글 드라이브에 자동 저장__
#     - 다만, __딥러닝 학습시킬 데이터가 문제인데 구글 드라이브에 저장 가능__
#     - 물론 개인이 공짜로 쓰는 구글 계정의 최대 용량은 15G이다.
#     - [Google Workspace](https://workspace.google.com/pricing.html) 서비스로 구글 드라이브에 대용량 데이터 저장가능
#
#
# __무료와 유료(Colab Pro) 차이__
#
# - 더 좋은 GPU 할당
#
#     - 무료: [K80](http://item.gmarket.co.kr/DetailView/Item.asp?goodscode=2060976040&GoodsSale=Y&jaehuid=200002657) GPU
#     - pro: [Tesla T4](http://item.gmarket.co.kr/DetailView/Item.asp?goodscode=1937752422&GoodsSale=Y&jaehuid=200002657) 또는 [Tesla P100](http://itempage3.auction.co.kr/DetailView.aspx?ItemNo=C304594068&frm3=V2) GPU
#
# - 고용량 RAM 사용 가능
#
#     - 무료: 12.72GB
#     - pro: 25.51GB
#
# - 더 긴 런타임
#
#     - 무료: 12시간
#     - pro: 24시간(단, 완전보장 못함)

# %% [markdown]
# ## Google Colab 사양 확인

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# * 플랫폼

# %%
import platform
platform.platform()
# Out:
# 'Linux-5.4.109+-x86_64-with-Ubuntu-18.04-bionic'

# %% [markdown]
# * 운영체제

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.5 LTS

# %% [markdown]
# * CPU 사양

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# * 메모리 사양

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13305328 kB
# MemFree:        10609704 kB
# MemAvailable:   12457124 kB
# Buffers:           87044 kB
# Cached:          1908044 kB
# SwapCached:            0 kB
# Active:           996072 kB
# Inactive:        1412188 kB
# Active(anon):     386880 kB
# Inactive(anon):      428 kB
# Active(file):     609192 kB
# Inactive(file):  1411760 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               156 kB
# Writeback:             0 kB
# AnonPages:        413148 kB
# Mapped:           227120 kB
# Shmem:              1192 kB
# KReclaimable:     135876 kB
# Slab:             185356 kB
# SReclaimable:     135876 kB
# SUnreclaim:        49480 kB
# KernelStack:        4512 kB
# PageTables:         5524 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6652664 kB
# Committed_AS:    3093500 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:       46748 kB
# VmallocChunk:          0 kB
# Percpu:             1424 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# FileHugePages:         0 kB
# FilePmdMapped:         0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:      160968 kB
# DirectMap2M:     5081088 kB
# DirectMap1G:    10485760 kB

# %% [markdown]
# * 디스크 사양

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay          69G   39G   30G  57% /
# tmpfs            64M     0   64M   0% /dev
# tmpfs           6.4G     0  6.4G   0% /sys/fs/cgroup
# shm             5.8G     0  5.8G   0% /dev/shm
# tmpfs           6.4G   24K  6.4G   1% /var/colab
# /dev/sda1        75G   41G   35G  54% /opt/bin
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %% [markdown]
# * 파이썬 버전

# %%
# !python --version
# Out:
# Python 3.7.10

# %% [markdown]
# ## Google Colab 런타임
# * Colab에서 고성능 하드웨어로 GPU나 TPU 사용 가능
# * 런타임 유형 변경(Change runtime type) 필요
#   + None: CPU만 사용
#   + GPU: 하드웨어 가속으로 GPU 사용
#   + TPU: 하드웨어 가속으로 TPU 사용

# %%
# !nvidia-smi
# Out:
# Thu May 13 09:11:00 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## 셀 조작

# %% [markdown]
# ### 셀 타입
# - Code Cells: May contain python code and ipython magic.
# - Markdown Cells: It can contain
#   - Markdown language
#   - HTML
#   - LATEX
# $$f(x)=ax^2+bx+c=0$$
# $$x = \frac{-b\pm\sqrt{b^2-4ac}}{2a}$$
#   - Image
#
# <img src="https://kr.mathworks.com/discovery/reinforcement-learning/_jcr_content/mainParsys3/discoverysubsection/mainParsys/image.adapt.1200.medium.png/1615456842093.png">
#
#   - Link
#
#       <예> [<b>Python Vs Javascript Vs Java Vs PHP Vs C | 2004-2019</b>](https://www.youtube.com/watch?v=NaZXxtggvWs)

# %% [markdown]
# ### 셀 타입 변경
# -**__코드셀로 변경: Ctrl/Cmd + M Y__**
#
# -**__텍스트셀로 변경: Ctrl/Cmd + M M__**

# %% [markdown]
# ### 셀 실행과 출력
#
# - 셀: 실행의 단위
# - 실행: 재생 버튼을 클릭 또는 단축기 사용
# - 실행후 실행 순서에 따라 일련변호가 부여됨.
#
# - 단축키
#   - Ctrl + Enter: 실행후 커서는 제자리
#   - Shift + Enter: 실행후 커서는 다음 셀
#   - Alt + Enter: 실행후 커서는 새로운 셀 삽입 및 이동

# %% [markdown]
# ### 셀 삽입/삭제
# - 현재 셀 위에 삽입: Ctrl/Cmd + M A
# - 현재 셀 아래에 삽입: Ctrl/Cmd + M B
# - 현재 셀 삭제: Ctrl/Cmd + M D 또는 쓰레기통 아이콘

# %% [markdown]
# ### 단축키 치트키
#
# - Ctrl + M H
#
# - PC 기반 Jupyter Notebook에서의 단축키는 Ctrl 키 없이 알파벳으로만.

# %% [markdown]
# ## 파일 저장 및 다운로드/업로드/import
#
# * Jupyter Notebook 환경에서 파일 저장 및 다운로드

# %%
# jupyter notebook magic command '%%writefile' for editing a filter
# %%writefile test.py

import matplotlib.pyplot as plt
import numpy as np

def plot():
  X=np.random.randn (50)
  Y = 2*X+np.random.randn(50)

  plt.plot(X,Y,'ro', label='Data')
  plt.grid()
  plt.legend()
  plt.show()
# Out:
# Writing test.py

# %%
# !cat test.py
# Out:
# import matplotlib.pyplot as plt
# import numpy as np
#
# def plot():
#   X=np.random.randn (50)
#   Y = 2*X+np.random.randn(50)
#
#   plt.plot(X,Y,'ro', label='Data')
#   plt.grid()
#   plt.legend()
#   plt.show()

# %%
# .py import
import test
test.plot()

# %%
from google.colab import files
files.download('test.py')

# %%
from google.colab import files
image = files.upload()
# Out:
#      <input type="file" id="files-1794247b-226d-493a-81d7-a99bc68207ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1794247b-226d-493a-81d7-a99bc68207ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Chrysanthemum.jpg to Chrysanthemum.jpg

# %%
# !ls -alF
# Out:
# total 1392
# drwxr-xr-x 1 root root   4096 May 13 10:30 ./
# drwxr-xr-x 1 root root   4096 May 13 09:54 ../
# drwxr-xr-x 4 root root   4096 May  6 13:43 .config/
# -rw-r--r-- 1 root root 777835 May 13 10:30 Penguins.jpg
# drwxr-xr-x 2 root root   4096 May 13 10:23 __pycache__/
# drwxr-xr-x 1 root root   4096 May  6 13:44 sample_data/
# -rw-r--r-- 1 root root    194 May 13 10:26 test.py
# -rw-r--r-- 1 root root 620888 May 13 10:30 Tulips.jpg

# %%
# upload한 이미지파일 시각화

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
from PIL import Image

print('type:', type(image))
key, _ = list(image.items())[0]
#img = Image.open(key)
img=Image.open("/content/drive/MyDrive/GitHub/GitHub/01 팽귄.jpg")
plt.imshow(img)
plt.show()
# Out:
# type: <class 'dict'>

# %% [markdown]
# ## Google Drive 연동
#
# * Google Colab은 Google Drive와 `mount`를 통해 쉽게 연동 가능
# * Google Drive에 소스 코드 저장 뿐만 아니라 파일을 열거나 저장 가능

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ll /content/drive/MyDrive/
# Out:
# total 3954
# drwx------ 2 root    4096 May 10 04:02  colab/
# drwx------ 2 root    4096 May 13 03:35 'Colab Notebooks'/
# drwx------ 2 root    4096 May 13 10:17  content/
# drwx------ 2 root    4096 May 10 02:30 'SIP 이해'/
# -rw------- 1 root 4031545 Oct 23  2019 'SIP 이해.pdf'

# %%
ll /content/drive/MyDrive/
# Out:
# total 12
# drwx------ 2 root 4096 May 10 04:02  colab/
# drwx------ 2 root 4096 May 13 03:35 'Colab Notebooks'/
# drwx------ 2 root 4096 May 13 10:17  content/

# %%
ls /content/drive/MyDrive/'Colab Notebooks'
# Out:
#  참고자료/
# '00_tensorflow_fundamentals.ipynb의 사본'
# 'Face_Mask_Detection_.ipynb의 사본'
# 'Lecture 1 - 인공지능 소개 및 Google Colab'/

# %% [markdown]
# ## 코렙 노트북파일 공유
#
# - 상단의 공유아이콘 클릭
# - 공유 권한(뷰어, 편집, 댓글) 설정에 주의

# %% [markdown]
# ## 깃허브(Github)
#
# - 깃허브는 분산 버전 관리 툴인 깃(Git)을 사용하는 프로젝트를 지원하는 웹호스팅 서비스
# - GitHub는 영리적인 서비스와 오픈소스를 위한 무상 서비스를 모두 제공
# - 가장 인기있는 오픈 소스 코드 저장소
# - [깃(Git)](https://git-scm.com)이 텍스트 명령어 입력 방식인데 반해, 깃허브는 GUI 방식
# - 2018년 마이크로소프트가 75억 달러에 깃허브 인수
#
# [가격정책](https://github.com/pricing)

# %% [markdown]
# ### 코렙에서  [Github](https://github.com/sangsin/HKCloud-Lectures)에 저장
#
# 1. 먼저 올릴 .ipynb 파일을 연다.
# 2. [파일]탭 - "GitHub 사본에 저장"을 클릭한다

# %% [markdown]
# ### 깃허브에서 Google Drive로
#
# 1. Clone할 [Github](https://github.com/sangsin/HKCloud-Lectures) 주소 복사해오기
# 2. 드라이브 마운트(Drive Mount) - 내 드라이브와 연동
# 3. 드라이브 내 원하는 경로로 이동
# 4. git clone을 활용하여 클론하기

# %%
# Mount Google Drive to VM instance.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd  /content/drive/MyDrive
# !git clone https://github.com/dohyeun/GitHub.git
# !ll
# Out:
# /content/drive/MyDrive
# Cloning into 'GitHub'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# /bin/bash: ll: command not found

# %% [markdown]
# # [Jupyter Notebook](https://jupyter.org/)
#
# Jupyter Notebook (formerly [IPython](https://ipython.org/) Notebooks) is an __open-source web-based interactive computational environment__ for creating Jupyter notebook documents.
#
# A Jupyter Notebook document is a JSON document, containing an ordered list of input/output cells which can contain __code, text (using Markdown), mathematics, plots and rich media__, usually ending with the "__.ipynb__" extension.

# %% [markdown]
# ## help()
#
# * 파이썬 객체에 대한 요약 정보와 사용법 보기

# %%
import tensorflow as tf
help(tf.square)
# Out:
# Help on function square in module tensorflow.python.ops.gen_math_ops:
#
# square(x, name=None)
#     Computes square of x element-wise.
#
#     I.e., \\(y = x * x = x^2\\).
#
#     >>> tf.math.square([-2., 0., 3.])
#     <tf.Tensor: shape=(3,), dtype=float32, numpy=array([4., 0., 9.], dtype=float32)>
#
#     Args:
#       x: A `Tensor`. Must be one of the following types: `bfloat16`, `half`, `float32`, `float64`, `int8`, `int16`, `int32`, `int64`, `complex64`, `complex128`.
#       name: A name for the operation (optional).
#
#     Returns:
#       A `Tensor`. Has the same type as `x`.
#
#       If `x` is a `SparseTensor`, returns
#       `SparseTensor(x.indices, tf.math.square(x.values, ...), x.dense_shape)`

# %% [markdown]
# ## ?로 설명 보기
#
# * 객체 요약 정보 및 사용법이 있는 docstring 보기

# %%
max?

# %%
li=['One', 'Two', 'Three']
li?

# %%
li.count?

# %%
def power(b,n):
  """b의 n승을 반환"""
  return pow(b,n)

# %%
power?

# %%
power??

# %% [markdown]
# ## 탭(tab) 자동완성
#
# * 객체와 모듈, 인터페이스의 내용을 자동 완성

# %%
li=['One', 'Two', 'Three']
li.append('four')
li.

# %% [markdown]
# ##와일드카드(wildcard) 매칭
#
# * 단어의 중간이나 마지막 글자로 매칭하여 객체나 속성 찾기

# %%
*Error?

# %%
str.*index*?

# %% [markdown]
# ## 매직 명령어(magic commands)
#
# * Jupyter Notebook 환경에서 파이썬 파일 저장 및 실행

# %%
# %%writefile hello.py
print("Hello Colab")
# Out:
# Overwriting hello.py

# %%
# %run: 외부 Python 스크립트를 실행 
# %run hello.py
# Out:
# Hello Colab

# %%
# %lsmagic: 현재 사용 가능한 Magic Command List
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %shell  %store  %sx  %system  %tb  %tensorflow_version  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%bigquery  %%capture  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%shell  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# * 코드 실행 시간 측정
#
# - %timeit: one line
# - %%timeit: multiple lines

# %%
# %%timeit?

# %%
# %timeit li = [n ** n for n in range(100)]
# Out:
# 10000 loops, best of 5: 42.3 µs per loop

# %%
# %%timeit
li = []
for n in range(100):
  li.append(n**n)
# Out:
# The slowest run took 4.81 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000 loops, best of 5: 46.7 µs per loop

# %% [markdown]
# ## 셸 명령어
#
# * 텍스트 기반의 셸 명령어 처리
# * `!` 문자를 명령어 앞에 붙여서 셸 명령어 사용 가능

# %% [markdown]
# * ls: 디렉토리 리스트 보기
# * cd: 디렉토리 변경
# * pwd: 현재 디렉토리
# * mkdir: 디렉토리 생성
# * cat: 파일 보기
# * cp: 디렉토리/파일 복사
# * rm: 디렉토리/파일 삭제

# %%
% cd /content/drive/  
# !pwd
# !ls

# %% [markdown]
# * !cd: 디렉토리 변경
#   * IPython에서는 임시 셸에서 실행
# * %cd: 지속적인 디렉토리 변경

# %%
# !cd MyDrive 
# !pwd
# !ls

# %%
# !cd MyDrive  && ls
# !pwd

# %%
# %cd MyDrive
# !pwd
# !ls

# %%
# %cd /content
# !mkdir tmp
# !ls

# %%
# !cat test.py

# %%
# !rm -r tmp  # -r: 디렉토리내 파일들 삭제후 디렉토리 삭제

# %%
# !ls tmp

# %% [markdown]
# ## 마크다운(Markdown)
#
# * 문법이 간단하고, 사용이 쉬움

# %% [markdown]
# ### 제목(Heading) 표시
#
# #### Heading 4
# ##### Heading 5
# ###### Heading 6

# %% [markdown]
# ### 목록(List) 구성

# %% [markdown]
# 1. First
# 2. Second
# 3. Third
# * 1단계
#   * 2단계
#     * 3단계

# %% [markdown]
# ### 폰트 스타일(Font Style)

# %% [markdown]
# **bold**
#
# __bold__
#
# *italic*
#
# _italic_
#
# ~~strike~~
#
# <u>underbar</u>

# %% [markdown]
# ### 링크

# %% [markdown]
# [Google](https://www.google.com)

# %% [markdown]
# ### 이미지

# %% [markdown]
# ![이미지](https://www.google.com/images/branding/googlelogo/2x/googlelogo_color_272x92dp.png)

# %% [markdown]
# ### 수평선

# %% [markdown]
# ---

# %% [markdown]
# ### 표

# %% [markdown]
# [링크 텍스트](https://)| C1 | C2 | C3  |
# |:---|---:|:---:|
# | D1 | D2 | D3 |

# %% [markdown]
# ### 방정식
#
# **CEE (Cross Entropy Error)**
# $$\tag {1} H(X) = E[h(x)] = E[-log(P(X)] = -\sum_{x \in X} P(x)\cdot log(P(x)$$
#
# **MSE (Mean Square Error)**
# \begin{equation*}
# MSE = \frac{1}{N} \sum_{i=1}^N (y_i - t_i)^2
# \end{equation*}
#
# **Quadratic Equation**
#
# 이차방정식 $f(x) = ax^2 + bx +c =0$ 의 해는 근의 공식에 의해 아래와 같이 구할 수 있다.
#
# $$ x =\frac { -b\pm \sqrt{(b^2 - 4ac)}}{2a}$$
